# %%
import zipfile
ZIP_PATH = "dataset_backup.zip"

with zipfile.ZipFile(ZIP_PATH, 'r') as zip_ref:
    zip_ref.extractall("./")

print("Dataset extracted successfully!")
# Out:
# Dataset extracted successfully!

# %%
from pathlib import Path

root = Path("/work/dev_notebooks/Lab/Khanjan_Damani/Updated_Aadhar_detection/dataset")

print("train exists:", (root / "train").exists())
print("valid exists:", (root / "valid").exists())
print("test exists:", (root / "test").exists())
# Out:
# train exists: True
# valid exists: True
# test exists: True
